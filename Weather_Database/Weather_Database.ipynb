# %%
import numpy as np
import pandas as pd
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 758

# %%
city_data=[]

print('Beginning of Data Retrieval')
print('------------------------------------')

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning of Data Retrieval
# ------------------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": weather_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    # Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | kodiak
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | khani
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | cabinda
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | pevek
# Processing Record 13 of Set 1 | constitucion
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | balangiga
# Processing Record 16 of Set 1 | portland
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | tiksi
# Processing Record 20 of Set 1 | iquique
# Processing Record 21 of Set 1 | faanui
# Processing Record 22 of Set 1 | rypefjord
# Processing Record 23 of Set 1 | laurel
# Processing Record 24 of Set 1 | kuliyapitiya
# Processing Record 25 of Set 1 | tessalit
# Processing Record 26 of Set 1 | hamilton
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | lata
# Processing Record 29 of Set 1 | shu
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | cherskiy
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | sitka
# Processing Record 34 of Set 1 | saldanha
# Processing Record 35 of Set 1 | torbay
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | solnechnyy
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | ewa beach
# Processing Record 40 of Set 1 | yangjiang
# Processing Record 41 of Set 1 | dolores
# Processing Record 42 of Set 1 | huangnihe
# Processing Record 43 of Set 1 | hasaki
# Processing Record 44 of Set 1 | half moon bay
# Processing Record 45 of Set 1 | kitimat
# Processing Record 46 of Set 1 | cayenne
# Processing Record 47 of Set 1 | asau
# Processing Record 48 of Set 1 | barrow
# Processing Record 49 of Set 1 | tuatapere
# Processing Record 50 of Set 1 | isangel
# Processing Record 1 of Set 2 | mabaruma
# Processing Record 2 of Set 2 | nishihara
# Processing Record 3 of Set 2 | katsuura
# Processing Record 4 of Set 2 | guaruja
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | kaitangata
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 2 | deputatskiy
# Processing Record 10 of Set 2 | mount isa
# Processing Record 11 of Set 2 | tucano
# Processing Record 12 of Set 2 | wilmington
# Processing Record 13 of Set 2 | vitim
# Processing Record 14 of Set 2 | luderitz
# Processing Record 15 of Set 2 | rocha
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 2 | borazjan
# Processing Record 19 of Set 2 | kahului
# Processing Record 20 of Set 2 | maningrida
# Processing Record 21 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 2 | bonthe
# Processing Record 23 of Set 2 | bereda
# Processing Record 24 of Set 2 | komoro
# Processing Record 25 of Set 2 | isla mujeres
# Processing Record 26 of Set 2 | abha
# Processing Record 27 of Set 2 | dien bien
# City not found. Skipping...
# Processing Record 28 of Set 2 | asfi
# Processing Record 29 of Set 2 | cidreira
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | chuy
# Processing Record 33 of Set 2 | port lincoln
# Processing Record 34 of Set 2 | nemuro
# Processing Record 35 of Set 2 | saint-augustin
# Processing Record 36 of Set 2 | husavik
# Processing Record 37 of Set 2 | mizpe ramon
# City not found. Skipping...
# Processing Record 38 of Set 2 | hualmay
# Processing Record 39 of Set 2 | sheridan
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | charters towers
# Processing Record 42 of Set 2 | buchanan
# Processing Record 43 of Set 2 | kalmunai
# Processing Record 44 of Set 2 | nhulunbuy
# Processing Record 45 of Set 2 | qaanaaq
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | bambous virieux
# Processing Record 49 of Set 2 | klembivka
# Processing Record 50 of Set 2 | oriximina
# Processing Record 1 of Set 3 | aldan
# Processing Record 2 of Set 3 | el balyana
# City not found. Skipping...
# Processing Record 3 of Set 3 | mormugao
# Processing Record 4 of Set 3 | vanimo
# Processing Record 5 of Set 3 | paamiut
# Processing Record 6 of Set 3 | hope
# Processing Record 7 of Set 3 | cockburn town
# Processing Record 8 of Set 3 | acajutla
# Processing Record 9 of Set 3 | ixtapa
# Processing Record 10 of Set 3 | uvat
# Processing Record 11 of Set 3 | lavrentiya
# Processing Record 12 of Set 3 | avarua
# Processing Record 13 of Set 3 | mayumba
# Processing Record 14 of Set 3 | tautira
# Processing Record 15 of Set 3 | merauke
# Processing Record 16 of Set 3 | port blair
# Processing Record 17 of Set 3 | groningen
# Processing Record 18 of Set 3 | dikson
# Processing Record 19 of Set 3 | jacareacanga
# Processing Record 20 of Set 3 | bacolod
# Processing Record 21 of Set 3 | menongue
# Processing Record 22 of Set 3 | atuona
# Processing Record 23 of Set 3 | chokurdakh
# Processing Record 24 of Set 3 | beisfjord
# Processing Record 25 of Set 3 | chapais
# Processing Record 26 of Set 3 | doha
# Processing Record 27 of Set 3 | tiruvidaimarudur
# Processing Record 28 of Set 3 | new norfolk
# Processing Record 29 of Set 3 | irece
# Processing Record 30 of Set 3 | norman wells
# Processing Record 31 of Set 3 | ostrovnoy
# Processing Record 32 of Set 3 | lebu
# Processing Record 33 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 3 | saint-pierre
# Processing Record 35 of Set 3 | hillsborough
# Processing Record 36 of Set 3 | blagoyevo
# Processing Record 37 of Set 3 | carnarvon
# Processing Record 38 of Set 3 | cape town
# Processing Record 39 of Set 3 | provideniya
# Processing Record 40 of Set 3 | esperance
# Processing Record 41 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 3 | kutum
# Processing Record 43 of Set 3 | touros
# Processing Record 44 of Set 3 | beloha
# Processing Record 45 of Set 3 | fort wellington
# Processing Record 46 of Set 3 | talnakh
# Processing Record 47 of Set 3 | izumo
# Processing Record 48 of Set 3 | poum
# Processing Record 49 of Set 3 | huilong
# Processing Record 50 of Set 3 | pak phanang
# Processing Record 1 of Set 4 | tacuarembo
# Processing Record 2 of Set 4 | nikel
# Processing Record 3 of Set 4 | pridonskoy
# Processing Record 4 of Set 4 | mackenzie
# Processing Record 5 of Set 4 | nampula
# Processing Record 6 of Set 4 | faya
# Processing Record 7 of Set 4 | port elizabeth
# Processing Record 8 of Set 4 | marquette
# Processing Record 9 of Set 4 | ribeira grande
# Processing Record 10 of Set 4 | pitimbu
# Processing Record 11 of Set 4 | komsomolskiy
# Processing Record 12 of Set 4 | atar
# Processing Record 13 of Set 4 | victoria
# Processing Record 14 of Set 4 | iqaluit
# Processing Record 15 of Set 4 | leningradskiy
# Processing Record 16 of Set 4 | angoram
# Processing Record 17 of Set 4 | kota tinggi
# Processing Record 18 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 4 | boyolangu
# Processing Record 20 of Set 4 | acarau
# Processing Record 21 of Set 4 | coihaique
# Processing Record 22 of Set 4 | lagos
# Processing Record 23 of Set 4 | the valley
# Processing Record 24 of Set 4 | pisco
# Processing Record 25 of Set 4 | nanortalik
# Processing Record 26 of Set 4 | mahebourg
# Processing Record 27 of Set 4 | honiara
# Processing Record 28 of Set 4 | bollnas
# Processing Record 29 of Set 4 | arraial do cabo
# Processing Record 30 of Set 4 | cabedelo
# Processing Record 31 of Set 4 | khasan
# Processing Record 32 of Set 4 | mount gambier
# Processing Record 33 of Set 4 | bengkulu
# Processing Record 34 of Set 4 | roros
# Processing Record 35 of Set 4 | bratsk
# Processing Record 36 of Set 4 | besancon
# Processing Record 37 of Set 4 | port keats
# Processing Record 38 of Set 4 | port hardy
# Processing Record 39 of Set 4 | udachnyy
# Processing Record 40 of Set 4 | san carlos de bariloche
# Processing Record 41 of Set 4 | nantucket
# Processing Record 42 of Set 4 | port-gentil
# Processing Record 43 of Set 4 | whitehorse
# Processing Record 44 of Set 4 | emilio carranza
# Processing Record 45 of Set 4 | taga
# Processing Record 46 of Set 4 | sorland
# Processing Record 47 of Set 4 | lookan
# Processing Record 48 of Set 4 | dali
# Processing Record 49 of Set 4 | seddon
# Processing Record 50 of Set 4 | smithers
# Processing Record 1 of Set 5 | sinnamary
# Processing Record 2 of Set 5 | lucea
# Processing Record 3 of Set 5 | dawlatabad
# Processing Record 4 of Set 5 | razdolinsk
# Processing Record 5 of Set 5 | khatanga
# Processing Record 6 of Set 5 | codrington
# Processing Record 7 of Set 5 | khargone
# Processing Record 8 of Set 5 | sakaiminato
# Processing Record 9 of Set 5 | morros
# Processing Record 10 of Set 5 | orocue
# Processing Record 11 of Set 5 | narsaq
# Processing Record 12 of Set 5 | bremerton
# Processing Record 13 of Set 5 | sharkan
# Processing Record 14 of Set 5 | la ronge
# Processing Record 15 of Set 5 | tatawin
# Processing Record 16 of Set 5 | meulaboh
# Processing Record 17 of Set 5 | kruisfontein
# Processing Record 18 of Set 5 | aklavik
# Processing Record 19 of Set 5 | santa isabel
# Processing Record 20 of Set 5 | salalah
# Processing Record 21 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 5 | tual
# Processing Record 23 of Set 5 | vostok
# Processing Record 24 of Set 5 | oranjestad
# Processing Record 25 of Set 5 | saskylakh
# Processing Record 26 of Set 5 | bogalusa
# Processing Record 27 of Set 5 | soledar
# Processing Record 28 of Set 5 | ardabil
# Processing Record 29 of Set 5 | avera
# Processing Record 30 of Set 5 | namie
# Processing Record 31 of Set 5 | mantua
# Processing Record 32 of Set 5 | vryheid
# Processing Record 33 of Set 5 | saint-philippe
# Processing Record 34 of Set 5 | rio gallegos
# Processing Record 35 of Set 5 | northam
# Processing Record 36 of Set 5 | shimoda
# Processing Record 37 of Set 5 | lebanon
# Processing Record 38 of Set 5 | chake chake
# Processing Record 39 of Set 5 | cosolapa
# Processing Record 40 of Set 5 | coquimbo
# Processing Record 41 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 42 of Set 5 | viedma
# Processing Record 43 of Set 5 | haines junction
# Processing Record 44 of Set 5 | sakata
# Processing Record 45 of Set 5 | micheweni
# Processing Record 46 of Set 5 | balaguer
# Processing Record 47 of Set 5 | yellowknife
# Processing Record 48 of Set 5 | yulara
# Processing Record 49 of Set 5 | los llanos de aridane
# Processing Record 50 of Set 5 | alofi
# Processing Record 1 of Set 6 | korla
# Processing Record 2 of Set 6 | beckley
# Processing Record 3 of Set 6 | wajid
# Processing Record 4 of Set 6 | sao felix do xingu
# Processing Record 5 of Set 6 | zhuji
# Processing Record 6 of Set 6 | hami
# Processing Record 7 of Set 6 | baruun-urt
# Processing Record 8 of Set 6 | port-cartier
# Processing Record 9 of Set 6 | lillooet
# Processing Record 10 of Set 6 | clyde river
# Processing Record 11 of Set 6 | emerald
# Processing Record 12 of Set 6 | rabo de peixe
# Processing Record 13 of Set 6 | constantine
# Processing Record 14 of Set 6 | lowestoft
# Processing Record 15 of Set 6 | okha
# Processing Record 16 of Set 6 | belle fourche
# Processing Record 17 of Set 6 | mittagong
# Processing Record 18 of Set 6 | sechura
# Processing Record 19 of Set 6 | leshukonskoye
# Processing Record 20 of Set 6 | nouadhibou
# Processing Record 21 of Set 6 | neckarsulm
# Processing Record 22 of Set 6 | felidhoo
# City not found. Skipping...
# Processing Record 23 of Set 6 | cabo san lucas
# Processing Record 24 of Set 6 | bonavista
# Processing Record 25 of Set 6 | lagoa
# Processing Record 26 of Set 6 | bethel
# Processing Record 27 of Set 6 | suntar
# Processing Record 28 of Set 6 | brigantine
# Processing Record 29 of Set 6 | camacha
# Processing Record 30 of Set 6 | maniitsoq
# Processing Record 31 of Set 6 | ciudad bolivar
# Processing Record 32 of Set 6 | pouembout
# Processing Record 33 of Set 6 | baykit
# Processing Record 34 of Set 6 | santona
# Processing Record 35 of Set 6 | airai
# Processing Record 36 of Set 6 | naryan-mar
# Processing Record 37 of Set 6 | alta
# Processing Record 38 of Set 6 | mananara
# Processing Record 39 of Set 6 | naftah
# City not found. Skipping...
# Processing Record 40 of Set 6 | necochea
# Processing Record 41 of Set 6 | saint george
# Processing Record 42 of Set 6 | waingapu
# Processing Record 43 of Set 6 | fortuna
# Processing Record 44 of Set 6 | vorozhba
# Processing Record 45 of Set 6 | gorey
# Processing Record 46 of Set 6 | alibag
# Processing Record 47 of Set 6 | guerrero negro
# Processing Record 48 of Set 6 | namatanai
# Processing Record 49 of Set 6 | upata
# Processing Record 50 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 7 | dunedin
# Processing Record 4 of Set 7 | zeya
# Processing Record 5 of Set 7 | karratha
# Processing Record 6 of Set 7 | roma
# Processing Record 7 of Set 7 | zapolyarnyy
# Processing Record 8 of Set 7 | karnobat
# Processing Record 9 of Set 7 | jizan
# Processing Record 10 of Set 7 | beyneu
# Processing Record 11 of Set 7 | skjaerhollen
# City not found. Skipping...
# Processing Record 12 of Set 7 | bobcaygeon
# Processing Record 13 of Set 7 | cartagena del chaira
# Processing Record 14 of Set 7 | barberton
# Processing Record 15 of Set 7 | fort nelson
# Processing Record 16 of Set 7 | padang
# Processing Record 17 of Set 7 | marawi
# Processing Record 18 of Set 7 | port alfred
# Processing Record 19 of Set 7 | mogadishu
# Processing Record 20 of Set 7 | broken hill
# Processing Record 21 of Set 7 | garowe
# Processing Record 22 of Set 7 | mwene-ditu
# Processing Record 23 of Set 7 | pangnirtung
# Processing Record 24 of Set 7 | anajatuba
# Processing Record 25 of Set 7 | semirom
# Processing Record 26 of Set 7 | xuddur
# Processing Record 27 of Set 7 | labuhan
# Processing Record 28 of Set 7 | georgetown
# Processing Record 29 of Set 7 | troitskoye
# Processing Record 30 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 31 of Set 7 | banda aceh
# Processing Record 32 of Set 7 | kota kinabalu
# Processing Record 33 of Set 7 | inhambane
# Processing Record 34 of Set 7 | hay river
# Processing Record 35 of Set 7 | lerwick
# Processing Record 36 of Set 7 | dzhebariki-khaya
# Processing Record 37 of Set 7 | ishigaki
# Processing Record 38 of Set 7 | teya
# Processing Record 39 of Set 7 | huai thalaeng
# Processing Record 40 of Set 7 | nelson bay
# Processing Record 41 of Set 7 | wollongong
# Processing Record 42 of Set 7 | akyab
# Processing Record 43 of Set 7 | baghmara
# Processing Record 44 of Set 7 | chany
# Processing Record 45 of Set 7 | kazachinskoye
# Processing Record 46 of Set 7 | bairiki
# Processing Record 47 of Set 7 | kieta
# Processing Record 48 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 7 | buxar
# Processing Record 50 of Set 7 | ajdabiya
# Processing Record 1 of Set 8 | shitanjing
# Processing Record 2 of Set 8 | berck
# Processing Record 3 of Set 8 | tomatlan
# Processing Record 4 of Set 8 | minot
# Processing Record 5 of Set 8 | east london
# Processing Record 6 of Set 8 | dengzhou
# Processing Record 7 of Set 8 | ararat
# Processing Record 8 of Set 8 | ahipara
# Processing Record 9 of Set 8 | ojinaga
# Processing Record 10 of Set 8 | progreso
# Processing Record 11 of Set 8 | tateyama
# Processing Record 12 of Set 8 | mbandaka
# Processing Record 13 of Set 8 | dorado
# Processing Record 14 of Set 8 | carutapera
# Processing Record 15 of Set 8 | haapiti
# Processing Record 16 of Set 8 | sendhwa
# Processing Record 17 of Set 8 | bolgatanga
# Processing Record 18 of Set 8 | kajaani
# Processing Record 19 of Set 8 | rondonopolis
# Processing Record 20 of Set 8 | sale
# Processing Record 21 of Set 8 | nurota
# Processing Record 22 of Set 8 | hovd
# Processing Record 23 of Set 8 | kerch
# Processing Record 24 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 8 | talara
# Processing Record 26 of Set 8 | jefferson city
# Processing Record 27 of Set 8 | longyearbyen
# Processing Record 28 of Set 8 | marquetalia
# Processing Record 29 of Set 8 | awash
# Processing Record 30 of Set 8 | dumas
# Processing Record 31 of Set 8 | toyooka
# Processing Record 32 of Set 8 | igrim
# Processing Record 33 of Set 8 | pacific grove
# Processing Record 34 of Set 8 | kloulklubed
# Processing Record 35 of Set 8 | flin flon
# Processing Record 36 of Set 8 | huangzhai
# Processing Record 37 of Set 8 | caravelas
# Processing Record 38 of Set 8 | college
# Processing Record 39 of Set 8 | nome
# Processing Record 40 of Set 8 | srednekolymsk
# Processing Record 41 of Set 8 | kano
# Processing Record 42 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 8 | concordia
# Processing Record 44 of Set 8 | uige
# Processing Record 45 of Set 8 | kununurra
# Processing Record 46 of Set 8 | banjar
# Processing Record 47 of Set 8 | sol-iletsk
# Processing Record 48 of Set 8 | mahibadhoo
# Processing Record 49 of Set 8 | lyubim
# Processing Record 50 of Set 8 | aksu
# Processing Record 1 of Set 9 | nyaunglebin
# Processing Record 2 of Set 9 | saint john
# Processing Record 3 of Set 9 | skjold
# Processing Record 4 of Set 9 | wau
# Processing Record 5 of Set 9 | samarai
# Processing Record 6 of Set 9 | soyo
# Processing Record 7 of Set 9 | ancud
# Processing Record 8 of Set 9 | andenes
# Processing Record 9 of Set 9 | fereydun kenar
# Processing Record 10 of Set 9 | sao jose da coroa grande
# Processing Record 11 of Set 9 | thompson
# Processing Record 12 of Set 9 | laminusa
# Processing Record 13 of Set 9 | mianwali
# Processing Record 14 of Set 9 | abeche
# Processing Record 15 of Set 9 | grand forks
# Processing Record 16 of Set 9 | klyuchi
# Processing Record 17 of Set 9 | bondoukou
# Processing Record 18 of Set 9 | qasigiannguit
# Processing Record 19 of Set 9 | henties bay
# Processing Record 20 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 9 | hambantota
# Processing Record 22 of Set 9 | ploemeur
# Processing Record 23 of Set 9 | kaputa
# Processing Record 24 of Set 9 | kishi
# Processing Record 25 of Set 9 | lamu
# Processing Record 26 of Set 9 | kalmar
# Processing Record 27 of Set 9 | bezhanitsy
# Processing Record 28 of Set 9 | hokitika
# Processing Record 29 of Set 9 | fuzhou
# Processing Record 30 of Set 9 | upington
# Processing Record 31 of Set 9 | hithadhoo
# Processing Record 32 of Set 9 | atherton
# Processing Record 33 of Set 9 | vaitape
# Processing Record 34 of Set 9 | shchelyayur
# City not found. Skipping...
# Processing Record 35 of Set 9 | kaeo
# Processing Record 36 of Set 9 | kaihua
# Processing Record 37 of Set 9 | klaksvik
# Processing Record 38 of Set 9 | margate
# Processing Record 39 of Set 9 | belmonte
# Processing Record 40 of Set 9 | souillac
# Processing Record 41 of Set 9 | chama
# Processing Record 42 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 9 | mana
# Processing Record 44 of Set 9 | ponta do sol
# Processing Record 45 of Set 9 | namibe
# Processing Record 46 of Set 9 | sonepur
# Processing Record 47 of Set 9 | usakos
# Processing Record 48 of Set 9 | san juan
# Processing Record 49 of Set 9 | am timan
# Processing Record 50 of Set 9 | walvis bay
# Processing Record 1 of Set 10 | behat
# Processing Record 2 of Set 10 | donauworth
# Processing Record 3 of Set 10 | madimba
# Processing Record 4 of Set 10 | santa rita
# Processing Record 5 of Set 10 | ternate
# Processing Record 6 of Set 10 | chifeng
# Processing Record 7 of Set 10 | beringovskiy
# Processing Record 8 of Set 10 | aswan
# Processing Record 9 of Set 10 | gobabis
# Processing Record 10 of Set 10 | kavaratti
# Processing Record 11 of Set 10 | bubaque
# Processing Record 12 of Set 10 | port hedland
# Processing Record 13 of Set 10 | sept-iles
# Processing Record 14 of Set 10 | caluquembe
# Processing Record 15 of Set 10 | jiuquan
# Processing Record 16 of Set 10 | ipubi
# Processing Record 17 of Set 10 | rincon de la victoria
# Processing Record 18 of Set 10 | xining
# Processing Record 19 of Set 10 | makat
# Processing Record 20 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 21 of Set 10 | sao filipe
# Processing Record 22 of Set 10 | tarabuco
# Processing Record 23 of Set 10 | sisophon
# Processing Record 24 of Set 10 | bucine
# Processing Record 25 of Set 10 | chirongui
# Processing Record 26 of Set 10 | kitgum
# Processing Record 27 of Set 10 | nioro
# Processing Record 28 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 29 of Set 10 | novo cruzeiro
# Processing Record 30 of Set 10 | imbituba
# Processing Record 31 of Set 10 | puerto del rosario
# Processing Record 32 of Set 10 | la paz
# Processing Record 33 of Set 10 | raisinghnagar
# Processing Record 34 of Set 10 | dafeng
# Processing Record 35 of Set 10 | la palma
# Processing Record 36 of Set 10 | santa lucia
# Processing Record 37 of Set 10 | ye
# City not found. Skipping...
# Processing Record 38 of Set 10 | vuktyl
# Processing Record 39 of Set 10 | eureka
# Processing Record 40 of Set 10 | issia
# Processing Record 41 of Set 10 | sao miguel do araguaia
# Processing Record 42 of Set 10 | chernyshevskiy
# Processing Record 43 of Set 10 | harwich
# Processing Record 44 of Set 10 | zhezkazgan
# Processing Record 45 of Set 10 | geraldton
# Processing Record 46 of Set 10 | pangody
# Processing Record 47 of Set 10 | laguna
# Processing Record 48 of Set 10 | muscat
# Processing Record 49 of Set 10 | saint-joseph
# Processing Record 50 of Set 10 | kavieng
# Processing Record 1 of Set 11 | bull savanna
# Processing Record 2 of Set 11 | sehithwa
# Processing Record 3 of Set 11 | nacozari
# Processing Record 4 of Set 11 | karlskoga
# Processing Record 5 of Set 11 | cerano
# Processing Record 6 of Set 11 | vao
# Processing Record 7 of Set 11 | twentynine palms
# Processing Record 8 of Set 11 | dingle
# Processing Record 9 of Set 11 | kovdor
# Processing Record 10 of Set 11 | ngaoundere
# Processing Record 11 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 11 | sergeyevka
# Processing Record 14 of Set 11 | bose
# Processing Record 15 of Set 11 | areosa
# Processing Record 16 of Set 11 | ikot ekpene
# Processing Record 17 of Set 11 | nouakchott
# Processing Record 18 of Set 11 | tumut
# Processing Record 19 of Set 11 | taoudenni
# Processing Record 20 of Set 11 | seoul
# Processing Record 21 of Set 11 | teahupoo
# Processing Record 22 of Set 11 | zorritos
# Processing Record 23 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 11 | gushikawa
# Processing Record 25 of Set 11 | lakes entrance
# Processing Record 26 of Set 11 | severo-kurilsk
# Processing Record 27 of Set 11 | vangaindrano
# Processing Record 28 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 11 | san patricio
# Processing Record 30 of Set 11 | antofagasta
# Processing Record 31 of Set 11 | great bend
# Processing Record 32 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 11 | luanda
# Processing Record 34 of Set 11 | tazovskiy
# Processing Record 35 of Set 11 | saeby
# Processing Record 36 of Set 11 | tura
# Processing Record 37 of Set 11 | lorengau
# Processing Record 38 of Set 11 | sangar
# Processing Record 39 of Set 11 | ilulissat
# Processing Record 40 of Set 11 | sovetskiy
# Processing Record 41 of Set 11 | yidu
# Processing Record 42 of Set 11 | ostersund
# Processing Record 43 of Set 11 | rantauprapat
# Processing Record 44 of Set 11 | nauta
# Processing Record 45 of Set 11 | balkhash
# Processing Record 46 of Set 11 | edd
# Processing Record 47 of Set 11 | zalari
# Processing Record 48 of Set 11 | takhtamygda
# Processing Record 49 of Set 11 | chara
# Processing Record 50 of Set 11 | kirakira
# Processing Record 1 of Set 12 | goderich
# Processing Record 2 of Set 12 | nyagan
# Processing Record 3 of Set 12 | chaozhou
# Processing Record 4 of Set 12 | abu samrah
# Processing Record 5 of Set 12 | bathsheba
# Processing Record 6 of Set 12 | ust-ishim
# Processing Record 7 of Set 12 | kuala terengganu
# Processing Record 8 of Set 12 | xinzhi
# Processing Record 9 of Set 12 | harindanga
# Processing Record 10 of Set 12 | lugovoy
# Processing Record 11 of Set 12 | tigil
# Processing Record 12 of Set 12 | vilhena
# Processing Record 13 of Set 12 | ambon
# Processing Record 14 of Set 12 | singaraja
# Processing Record 15 of Set 12 | athabasca
# Processing Record 16 of Set 12 | dharchula
# Processing Record 17 of Set 12 | coahuayana
# Processing Record 18 of Set 12 | zephyrhills
# Processing Record 19 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 20 of Set 12 | cape coast
# Processing Record 21 of Set 12 | jaguarari
# Processing Record 22 of Set 12 | te anau
# Processing Record 23 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 12 | bilma
# Processing Record 25 of Set 12 | saint-francois
# Processing Record 26 of Set 12 | waipawa
# Processing Record 27 of Set 12 | shenjiamen
# Processing Record 28 of Set 12 | richards bay
# Processing Record 29 of Set 12 | taft
# Processing Record 30 of Set 12 | sola
# Processing Record 31 of Set 12 | bilibino
# Processing Record 32 of Set 12 | kapit
# Processing Record 33 of Set 12 | centralia
# Processing Record 34 of Set 12 | sorong
# Processing Record 35 of Set 12 | egvekinot
# Processing Record 36 of Set 12 | tarakan
# Processing Record 37 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 38 of Set 12 | daniel flores
# Processing Record 39 of Set 12 | staunton
# Processing Record 40 of Set 12 | non sung
# Processing Record 41 of Set 12 | muros
# Processing Record 42 of Set 12 | fort frances
# Processing Record 43 of Set 12 | malatya
# Processing Record 44 of Set 12 | ugoofaaru
# Processing Record 45 of Set 12 | foumban
# Processing Record 46 of Set 12 | ferme-neuve
# Processing Record 47 of Set 12 | tahe
# Processing Record 48 of Set 12 | bouillon
# Processing Record 49 of Set 12 | boa vista
# Processing Record 50 of Set 12 | vestmannaeyjar
# Processing Record 1 of Set 13 | panjab
# Processing Record 2 of Set 13 | broome
# Processing Record 3 of Set 13 | olafsvik
# Processing Record 4 of Set 13 | bocaranga
# City not found. Skipping...
# Processing Record 5 of Set 13 | jesup
# Processing Record 6 of Set 13 | safford
# Processing Record 7 of Set 13 | la baule-escoublac
# Processing Record 8 of Set 13 | bryan
# Processing Record 9 of Set 13 | corrente
# Processing Record 10 of Set 13 | dargaville
# Processing Record 11 of Set 13 | palana
# Processing Record 12 of Set 13 | tungawan
# Processing Record 13 of Set 13 | cap malheureux
# Processing Record 14 of Set 13 | kautokeino
# Processing Record 15 of Set 13 | ust-omchug
# Processing Record 16 of Set 13 | diapaga
# Processing Record 17 of Set 13 | lompoc
# Processing Record 18 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 13 | rio grande
# Processing Record 20 of Set 13 | jaciara
# Processing Record 21 of Set 13 | mweka
# Processing Record 22 of Set 13 | shahr-e babak
# Processing Record 23 of Set 13 | yeniseysk
# Processing Record 24 of Set 13 | certaldo
# Processing Record 25 of Set 13 | tambura
# Processing Record 26 of Set 13 | grand gaube
# Processing Record 27 of Set 13 | jalu
# Processing Record 28 of Set 13 | yatou
# Processing Record 29 of Set 13 | sao joao da barra
# Processing Record 30 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 31 of Set 13 | las cruces
# Processing Record 32 of Set 13 | jumla
# Processing Record 33 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 13 | lyngdal
# Processing Record 35 of Set 13 | mahroni
# Processing Record 36 of Set 13 | makakilo city
# Processing Record 37 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 13 | sete
# Processing Record 39 of Set 13 | boende
# Processing Record 40 of Set 13 | dongsheng
# Processing Record 41 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 42 of Set 13 | huamuxtitlan
# Processing Record 43 of Set 13 | rawson
# Processing Record 44 of Set 13 | yar-sale
# Processing Record 45 of Set 13 | itarema
# Processing Record 46 of Set 13 | pulaski
# Processing Record 47 of Set 13 | tarauaca
# Processing Record 48 of Set 13 | aleksandrovka
# Processing Record 49 of Set 13 | severnyy
# Processing Record 50 of Set 13 | severodvinsk
# Processing Record 1 of Set 14 | sakakah
# Processing Record 2 of Set 14 | port moresby
# Processing Record 3 of Set 14 | matara
# Processing Record 4 of Set 14 | juneau
# Processing Record 5 of Set 14 | zhigansk
# Processing Record 6 of Set 14 | dhanaura
# Processing Record 7 of Set 14 | aykhal
# Processing Record 8 of Set 14 | shenxian
# Processing Record 9 of Set 14 | beira
# Processing Record 10 of Set 14 | luena
# Processing Record 11 of Set 14 | fukue
# Processing Record 12 of Set 14 | biloxi
# Processing Record 13 of Set 14 | yaring
# Processing Record 14 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 15 of Set 14 | guangyuan
# Processing Record 16 of Set 14 | russell
# Processing Record 17 of Set 14 | christchurch
# Processing Record 18 of Set 14 | polunochnoye
# Processing Record 19 of Set 14 | puerto rico
# Processing Record 20 of Set 14 | san quintin
# Processing Record 21 of Set 14 | lamar
# Processing Record 22 of Set 14 | palmer
# Processing Record 23 of Set 14 | alice springs
# Processing Record 24 of Set 14 | tukums
# Processing Record 25 of Set 14 | puerto berrio
# Processing Record 26 of Set 14 | port-de-paix
# City not found. Skipping...
# Processing Record 27 of Set 14 | binzhou
# Processing Record 28 of Set 14 | tulancingo
# Processing Record 29 of Set 14 | nara
# Processing Record 30 of Set 14 | catamarca
# Processing Record 31 of Set 14 | takoradi
# Processing Record 32 of Set 14 | toora-khem
# Processing Record 33 of Set 14 | alekseyevsk
# Processing Record 34 of Set 14 | cairns
# Processing Record 35 of Set 14 | inverness
# Processing Record 36 of Set 14 | alyangula
# Processing Record 37 of Set 14 | auki
# Processing Record 38 of Set 14 | daytona beach
# Processing Record 39 of Set 14 | katsina
# Processing Record 40 of Set 14 | semnan
# Processing Record 41 of Set 14 | tingrela
# City not found. Skipping...
# Processing Record 42 of Set 14 | havre-saint-pierre
# Processing Record 43 of Set 14 | burevestnik
# Processing Record 44 of Set 14 | strezhevoy
# Processing Record 45 of Set 14 | pilibhit
# Processing Record 46 of Set 14 | terney
# Processing Record 47 of Set 14 | wattegama
# Processing Record 48 of Set 14 | talipparamba
# Processing Record 49 of Set 14 | luau
# Processing Record 50 of Set 14 | namwala
# Processing Record 1 of Set 15 | hofn
# Processing Record 2 of Set 15 | mysliborz
# Processing Record 3 of Set 15 | ilheus
# Processing Record 4 of Set 15 | lodja
# Processing Record 5 of Set 15 | ulladulla
# Processing Record 6 of Set 15 | san pedro
# Processing Record 7 of Set 15 | makung
# City not found. Skipping...
# Processing Record 8 of Set 15 | rorvik
# Processing Record 9 of Set 15 | sisimiut
# Processing Record 10 of Set 15 | aguada de pasajeros
# Processing Record 11 of Set 15 | maceio
# Processing Record 12 of Set 15 | quang ngai
# Processing Record 13 of Set 15 | anloga
# Processing Record 14 of Set 15 | zhangye
# Processing Record 15 of Set 15 | bairnsdale
# Processing Record 16 of Set 15 | pimentel
# Processing Record 17 of Set 15 | phun phin
# City not found. Skipping...
# Processing Record 18 of Set 15 | luba
# Processing Record 19 of Set 15 | westport
# Processing Record 20 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 21 of Set 15 | namanyere
# Processing Record 22 of Set 15 | riyadh
# Processing Record 23 of Set 15 | matagami
# Processing Record 24 of Set 15 | rumford
# Processing Record 25 of Set 15 | atambua
# Processing Record 26 of Set 15 | acapulco
# Processing Record 27 of Set 15 | bodden town
# Processing Record 28 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 15 | mesto albrechtice
# Processing Record 30 of Set 15 | oyama
# Processing Record 31 of Set 15 | zhuhai
# Processing Record 32 of Set 15 | bojnurd
# Processing Record 33 of Set 15 | havoysund
# Processing Record 34 of Set 15 | gat
# Processing Record 35 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 36 of Set 15 | shiyan
# Processing Record 37 of Set 15 | avdon
# Processing Record 38 of Set 15 | buqayq
# City not found. Skipping...
# Processing Record 39 of Set 15 | newton
# Processing Record 40 of Set 15 | diamantino
# Processing Record 41 of Set 15 | novomykolayivka
# Processing Record 42 of Set 15 | berezovyy
# Processing Record 43 of Set 15 | belyy yar
# Processing Record 44 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 15 | nago
# Processing Record 46 of Set 15 | barcelos
# Processing Record 47 of Set 15 | port washington
# Processing Record 48 of Set 15 | raga
# Processing Record 49 of Set 15 | pandan
# Processing Record 50 of Set 15 | kenora
# Processing Record 1 of Set 16 | unai
# Processing Record 2 of Set 16 | lufilufi
# Processing Record 3 of Set 16 | camopi
# Processing Record 4 of Set 16 | hailar
# Processing Record 5 of Set 16 | amga
# Processing Record 6 of Set 16 | gisborne
# Processing Record 7 of Set 16 | gillette
# Processing Record 8 of Set 16 | talaya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df = city_data_df[["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Jamestown      US  42.0970  -79.2353     72.99        73          40
# 1         Vaini      TO -21.2000 -175.2000     77.16        83          75
# 2       Mataura      NZ -46.1927  168.8643     47.48        88         100
# 3       Rikitea      PF -23.1203 -134.9692     74.62        80          97
# 4        Kodiak      US  57.7900 -152.4072     47.71        49           1
# 5    Bredasdorp      ZA -34.5322   20.0403     61.29        87          70
# 6         Khani      GE  41.9563   42.9566     49.57        76           3
# 7  Punta Arenas      CL -53.1500  -70.9167     51.91        37          20
# 8       Cabinda      AO  -5.5500   12.2000     76.23        79         100
# 9        Albany      US  42.6001  -73.9662     66.16        80          95
#
#    Wind Speed Current Description
# 0        5.99    scattered clouds
# 1        4.61       broken clouds
# 2        2.59          light rain
# 3       19.73     overcast clouds
# 4        3.44           clear sky
# 5        3.44       broken clouds
# 6        4.50           clear sky
# 7       31.07          few clouds
# 8        9.08     overcast clouds
# 9        6.55     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
